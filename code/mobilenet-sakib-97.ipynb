# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import seaborn as sns
import os
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D
from keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve, auc
# Out:
# 2024-07-07 14:02:37.521337: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-07 14:02:37.521464: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-07 14:02:37.670576: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# # Google colab connection
# from google.colab import drive
# drive.mount('/content/drive')
# !unzip "/content/dataset.zip"

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the directory paths
data_dir = '/kaggle/input/saadnewdataset/dataset'
img_size = (224, 224)
batch_size = 32

# Create ImageDataGenerator instances for train, validation, and test sets with augmentation for training set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=60,
    width_shift_range=0.5,
    height_shift_range=0.5,
    shear_range=0.5,
    zoom_range=0.5,
    horizontal_flip=True,
    validation_split=0.3  # Increase validation split to 30%
)

validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=True
)
# Out:
# Found 3725 images belonging to 10 classes.
# Found 1589 images belonging to 10 classes.

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.regularizers import l2

# Load the ResNet50 model pre-trained on ImageNet
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add custom layers on top of the base model
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(32, activation='relu')(x)  # Reduce the number of units
x = Dropout(0.5)(x)  # Increase dropout
predictions = Dense(10, activation='softmax')(x)  # Assuming you have 10 classes

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Make all layers trainable for fine-tuning
for layer in base_model.layers:
    layer.trainable = True

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Define callbacks
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, min_lr=1e-7)

# Train the model
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=[checkpoint, early_stopping, reduce_lr]
)
# Out:
# Epoch 1/50
#   1/117 ━━━━━━━━━━━━━━━━━━━━ 1:17:45 40s/step - accuracy: 0.1250 - loss: 3.1131
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720361011.973188     125 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1720361012.020129     125 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  65/117 ━━━━━━━━━━━━━━━━━━━━ 38s 749ms/step - accuracy: 0.1190 - loss: 3.0734
# W0000 00:00:1720361059.911740     123 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - accuracy: 0.1174 - loss: 3.0250
# W0000 00:00:1720361085.402248     122 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1720361097.708437     125 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 126s 742ms/step - accuracy: 0.1173 - loss: 3.0239 - val_accuracy: 0.1164 - val_loss: 2.5557 - learning_rate: 1.0000e-05
# Epoch 2/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 380ms/step - accuracy: 0.1123 - loss: 2.5754 - val_accuracy: 0.1580 - val_loss: 2.2418 - learning_rate: 1.0000e-05
# Epoch 3/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 381ms/step - accuracy: 0.1233 - loss: 2.3989 - val_accuracy: 0.3071 - val_loss: 2.0095 - learning_rate: 1.0000e-05
# Epoch 4/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 376ms/step - accuracy: 0.1579 - loss: 2.2908 - val_accuracy: 0.4021 - val_loss: 1.8978 - learning_rate: 1.0000e-05
# Epoch 5/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 381ms/step - accuracy: 0.1784 - loss: 2.2377 - val_accuracy: 0.4418 - val_loss: 1.7712 - learning_rate: 1.0000e-05
# Epoch 6/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.1897 - loss: 2.1746 - val_accuracy: 0.5085 - val_loss: 1.6381 - learning_rate: 1.0000e-05
# Epoch 7/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 378ms/step - accuracy: 0.2005 - loss: 2.1249 - val_accuracy: 0.5614 - val_loss: 1.5094 - learning_rate: 1.0000e-05
# Epoch 8/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 396ms/step - accuracy: 0.2322 - loss: 2.0868 - val_accuracy: 0.6098 - val_loss: 1.3700 - learning_rate: 1.0000e-05
# Epoch 9/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 377ms/step - accuracy: 0.2564 - loss: 2.0078 - val_accuracy: 0.6520 - val_loss: 1.2619 - learning_rate: 1.0000e-05
# Epoch 10/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 382ms/step - accuracy: 0.2661 - loss: 1.9633 - val_accuracy: 0.7130 - val_loss: 1.1221 - learning_rate: 1.0000e-05
# Epoch 11/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.2880 - loss: 1.9282 - val_accuracy: 0.7439 - val_loss: 1.0278 - learning_rate: 1.0000e-05
# Epoch 12/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 380ms/step - accuracy: 0.3338 - loss: 1.8624 - val_accuracy: 0.7533 - val_loss: 0.9390 - learning_rate: 1.0000e-05
# Epoch 13/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.3230 - loss: 1.8128 - val_accuracy: 0.7778 - val_loss: 0.8616 - learning_rate: 1.0000e-05
# Epoch 14/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 377ms/step - accuracy: 0.3464 - loss: 1.7748 - val_accuracy: 0.8068 - val_loss: 0.7762 - learning_rate: 1.0000e-05
# Epoch 15/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.3714 - loss: 1.7502 - val_accuracy: 0.8225 - val_loss: 0.7051 - learning_rate: 1.0000e-05
# Epoch 16/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.3874 - loss: 1.6878 - val_accuracy: 0.8402 - val_loss: 0.6516 - learning_rate: 1.0000e-05
# Epoch 17/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 377ms/step - accuracy: 0.4090 - loss: 1.6411 - val_accuracy: 0.8609 - val_loss: 0.5863 - learning_rate: 1.0000e-05
# Epoch 18/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 376ms/step - accuracy: 0.3959 - loss: 1.6446 - val_accuracy: 0.8829 - val_loss: 0.5325 - learning_rate: 1.0000e-05
# Epoch 19/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.4142 - loss: 1.6126 - val_accuracy: 0.8861 - val_loss: 0.4872 - learning_rate: 1.0000e-05
# Epoch 20/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 377ms/step - accuracy: 0.4417 - loss: 1.5529 - val_accuracy: 0.8949 - val_loss: 0.4398 - learning_rate: 1.0000e-05
# Epoch 21/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.4373 - loss: 1.5218 - val_accuracy: 0.9012 - val_loss: 0.4141 - learning_rate: 1.0000e-05
# Epoch 22/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 46s 375ms/step - accuracy: 0.4737 - loss: 1.4715 - val_accuracy: 0.9100 - val_loss: 0.3879 - learning_rate: 1.0000e-05
# Epoch 23/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.4715 - loss: 1.4580 - val_accuracy: 0.9138 - val_loss: 0.3597 - learning_rate: 1.0000e-05
# Epoch 24/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 380ms/step - accuracy: 0.4946 - loss: 1.4176 - val_accuracy: 0.9207 - val_loss: 0.3431 - learning_rate: 1.0000e-05
# Epoch 25/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 381ms/step - accuracy: 0.5107 - loss: 1.3741 - val_accuracy: 0.9220 - val_loss: 0.3075 - learning_rate: 1.0000e-05
# Epoch 26/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 382ms/step - accuracy: 0.5178 - loss: 1.3574 - val_accuracy: 0.9308 - val_loss: 0.2941 - learning_rate: 1.0000e-05
# Epoch 27/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 374ms/step - accuracy: 0.5366 - loss: 1.3227 - val_accuracy: 0.9308 - val_loss: 0.2726 - learning_rate: 1.0000e-05
# Epoch 28/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 381ms/step - accuracy: 0.5300 - loss: 1.3287 - val_accuracy: 0.9434 - val_loss: 0.2490 - learning_rate: 1.0000e-05
# Epoch 29/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 385ms/step - accuracy: 0.5425 - loss: 1.2995 - val_accuracy: 0.9440 - val_loss: 0.2297 - learning_rate: 1.0000e-05
# Epoch 30/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 377ms/step - accuracy: 0.5397 - loss: 1.2810 - val_accuracy: 0.9371 - val_loss: 0.2240 - learning_rate: 1.0000e-05
# Epoch 31/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 386ms/step - accuracy: 0.5759 - loss: 1.2114 - val_accuracy: 0.9484 - val_loss: 0.2072 - learning_rate: 1.0000e-05
# Epoch 32/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 381ms/step - accuracy: 0.5683 - loss: 1.1926 - val_accuracy: 0.9509 - val_loss: 0.1913 - learning_rate: 1.0000e-05
# Epoch 33/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.5414 - loss: 1.2915 - val_accuracy: 0.9547 - val_loss: 0.1845 - learning_rate: 1.0000e-05
# Epoch 34/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 378ms/step - accuracy: 0.5916 - loss: 1.2024 - val_accuracy: 0.9541 - val_loss: 0.1760 - learning_rate: 1.0000e-05
# Epoch 35/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 378ms/step - accuracy: 0.5807 - loss: 1.1927 - val_accuracy: 0.9541 - val_loss: 0.1712 - learning_rate: 1.0000e-05
# Epoch 36/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 46s 371ms/step - accuracy: 0.5746 - loss: 1.1917 - val_accuracy: 0.9522 - val_loss: 0.1645 - learning_rate: 1.0000e-05
# Epoch 37/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 378ms/step - accuracy: 0.5859 - loss: 1.1791 - val_accuracy: 0.9553 - val_loss: 0.1580 - learning_rate: 1.0000e-05
# Epoch 38/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 46s 374ms/step - accuracy: 0.5999 - loss: 1.1616 - val_accuracy: 0.9622 - val_loss: 0.1497 - learning_rate: 1.0000e-05
# Epoch 39/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 380ms/step - accuracy: 0.5914 - loss: 1.1473 - val_accuracy: 0.9629 - val_loss: 0.1426 - learning_rate: 1.0000e-05
# Epoch 40/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 376ms/step - accuracy: 0.6196 - loss: 1.1060 - val_accuracy: 0.9648 - val_loss: 0.1342 - learning_rate: 1.0000e-05
# Epoch 41/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 46s 372ms/step - accuracy: 0.6116 - loss: 1.0974 - val_accuracy: 0.9654 - val_loss: 0.1309 - learning_rate: 1.0000e-05
# Epoch 42/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 380ms/step - accuracy: 0.6121 - loss: 1.0881 - val_accuracy: 0.9673 - val_loss: 0.1241 - learning_rate: 1.0000e-05
# Epoch 43/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 384ms/step - accuracy: 0.6083 - loss: 1.1137 - val_accuracy: 0.9648 - val_loss: 0.1250 - learning_rate: 1.0000e-05
# Epoch 44/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 50s 400ms/step - accuracy: 0.6151 - loss: 1.0893 - val_accuracy: 0.9666 - val_loss: 0.1224 - learning_rate: 1.0000e-05
# Epoch 45/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 390ms/step - accuracy: 0.6325 - loss: 1.0666 - val_accuracy: 0.9666 - val_loss: 0.1185 - learning_rate: 1.0000e-05
# Epoch 46/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 392ms/step - accuracy: 0.6280 - loss: 1.0469 - val_accuracy: 0.9698 - val_loss: 0.1108 - learning_rate: 1.0000e-05
# Epoch 47/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 395ms/step - accuracy: 0.6469 - loss: 1.0288 - val_accuracy: 0.9704 - val_loss: 0.1072 - learning_rate: 1.0000e-05
# Epoch 48/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 378ms/step - accuracy: 0.6375 - loss: 1.0533 - val_accuracy: 0.9692 - val_loss: 0.1076 - learning_rate: 1.0000e-05
# Epoch 49/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 46s 372ms/step - accuracy: 0.6225 - loss: 1.0772 - val_accuracy: 0.9704 - val_loss: 0.1014 - learning_rate: 1.0000e-05
# Epoch 50/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 46s 371ms/step - accuracy: 0.6424 - loss: 1.0009 - val_accuracy: 0.9736 - val_loss: 0.0980 - learning_rate: 1.0000e-05

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve, auc, accuracy_score

# Recheck Data Generators
test_generator = test_datagen.flow_from_directory(
    '/kaggle/input/saadnewdataset/dataset',  # Make sure this directory is correct
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # Ensure no shuffling for consistency in predictions
)

# 1. Evaluate model on the test set
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy from evaluate: {test_acc * 100:.2f}%')


# Evaluate the model on test set
predictions = model.predict(test_generator)
y_true = test_generator.classes
y_pred = np.argmax(predictions, axis=1)

# Calculate accuracy score
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot confusion matrix using Seaborn
plt.figure(figsize=(15, 15))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# Classification report
print("Classification Report:")
print(classification_report(y_true, y_pred))

# Calculate overall ROC AUC score
roc_auc = roc_auc_score(tf.keras.utils.to_categorical(y_true), predictions, average='macro')
print("Overall ROC AUC Score:", roc_auc)

# Plot ROC curve
fpr, tpr, _ = roc_curve(tf.keras.utils.to_categorical(y_true).ravel(), predictions.ravel())
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.5f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve EfficientNet')
plt.legend(loc="lower right")
plt.show()

# Plot loss and accuracy per epoch
plt.figure(figsize=(12, 6))

# Plot training loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Found 5314 images belonging to 10 classes.
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9677 - loss: 0.1135
# W0000 00:00:1720363419.920970     123 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Test accuracy from evaluate: 97.18%
#   5/167 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step
# W0000 00:00:1720363421.818956     122 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step
# W0000 00:00:1720363431.332000     125 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Accuracy: 0.9717726759503199
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       526
#            1       0.97      0.95      0.96       534
#            2       0.99      0.97      0.98       533
#            3       0.99      0.98      0.98       531
#            4       0.97      1.00      0.98       532
#            5       0.92      0.98      0.95       532
#            6       0.99      0.94      0.96       532
#            7       0.97      0.99      0.98       533
#            8       0.98      0.98      0.98       531
#            9       0.94      0.97      0.96       530
#
#     accuracy                           0.97      5314
#    macro avg       0.97      0.97      0.97      5314
# weighted avg       0.97      0.97      0.97      5314
#
# Overall ROC AUC Score: 0.9994147440999497
