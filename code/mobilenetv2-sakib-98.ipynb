# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import seaborn as sns
import os
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D
from keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve, auc
# Out:
# 2024-07-06 17:22:10.319769: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-06 17:22:10.319867: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-06 17:22:10.429566: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# # Google colab connection
# from google.colab import drive
# drive.mount('/content/drive')
# !unzip "/content/dataset.zip"

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the directory paths
data_dir = '/kaggle/input/saadnewdataset/dataset'
img_size = (224, 224)
batch_size = 32

# Create ImageDataGenerator instances for train, validation, and test sets with augmentation for training set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=60,
    width_shift_range=0.5,
    height_shift_range=0.5,
    shear_range=0.5,
    zoom_range=0.5,
    horizontal_flip=True,
    validation_split=0.3  # Increase validation split to 30%
)

validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=True
)
# Out:
# Found 3725 images belonging to 10 classes.
# Found 1589 images belonging to 10 classes.

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.regularizers import l2

# Load the ResNet50 model pre-trained on ImageNet
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add custom layers on top of the base model
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(64, activation='relu')(x)  # Reduce the number of units
x = Dropout(0.5)(x)  # Increase dropout
predictions = Dense(10, activation='softmax')(x)  # Assuming you have 10 classes

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Make all layers trainable for fine-tuning
for layer in base_model.layers:
    layer.trainable = True

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Define callbacks
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, min_lr=1e-7)

# Train the model
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=[checkpoint, early_stopping, reduce_lr]
)
# Out:
# Epoch 1/50
#   1/117 ━━━━━━━━━━━━━━━━━━━━ 1:47:10 55s/step - accuracy: 0.0625 - loss: 2.7104
# W0000 00:00:1720290767.647268     178 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  46/117 ━━━━━━━━━━━━━━━━━━━━ 1:06 941ms/step - accuracy: 0.0908 - loss: 2.7659
# W0000 00:00:1720290809.928413     179 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 587ms/step - accuracy: 0.0988 - loss: 2.7292
# W0000 00:00:1720290839.443371     180 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1720290846.114260     180 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 135s 682ms/step - accuracy: 0.0988 - loss: 2.7286 - val_accuracy: 0.1447 - val_loss: 2.4737 - learning_rate: 1.0000e-05
# Epoch 2/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 389ms/step - accuracy: 0.1252 - loss: 2.4663 - val_accuracy: 0.1913 - val_loss: 2.3633 - learning_rate: 1.0000e-05
# Epoch 3/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 383ms/step - accuracy: 0.1524 - loss: 2.3286 - val_accuracy: 0.2291 - val_loss: 2.2694 - learning_rate: 1.0000e-05
# Epoch 4/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 383ms/step - accuracy: 0.1425 - loss: 2.3083 - val_accuracy: 0.2473 - val_loss: 2.1846 - learning_rate: 1.0000e-05
# Epoch 5/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 383ms/step - accuracy: 0.1683 - loss: 2.2239 - val_accuracy: 0.2530 - val_loss: 2.0994 - learning_rate: 1.0000e-05
# Epoch 6/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 387ms/step - accuracy: 0.2331 - loss: 2.1480 - val_accuracy: 0.2895 - val_loss: 1.9765 - learning_rate: 1.0000e-05
# Epoch 7/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 391ms/step - accuracy: 0.2632 - loss: 2.0698 - val_accuracy: 0.3197 - val_loss: 1.8579 - learning_rate: 1.0000e-05
# Epoch 8/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 385ms/step - accuracy: 0.3049 - loss: 1.9852 - val_accuracy: 0.3763 - val_loss: 1.6953 - learning_rate: 1.0000e-05
# Epoch 9/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 381ms/step - accuracy: 0.3241 - loss: 1.9039 - val_accuracy: 0.4179 - val_loss: 1.5483 - learning_rate: 1.0000e-05
# Epoch 10/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 388ms/step - accuracy: 0.3723 - loss: 1.7974 - val_accuracy: 0.5104 - val_loss: 1.3806 - learning_rate: 1.0000e-05
# Epoch 11/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 389ms/step - accuracy: 0.4027 - loss: 1.6838 - val_accuracy: 0.6174 - val_loss: 1.2018 - learning_rate: 1.0000e-05
# Epoch 12/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 387ms/step - accuracy: 0.4387 - loss: 1.6139 - val_accuracy: 0.6715 - val_loss: 1.0688 - learning_rate: 1.0000e-05
# Epoch 13/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 395ms/step - accuracy: 0.4608 - loss: 1.5033 - val_accuracy: 0.7527 - val_loss: 0.8943 - learning_rate: 1.0000e-05
# Epoch 14/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 395ms/step - accuracy: 0.4951 - loss: 1.4514 - val_accuracy: 0.7961 - val_loss: 0.7719 - learning_rate: 1.0000e-05
# Epoch 15/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 384ms/step - accuracy: 0.5318 - loss: 1.3732 - val_accuracy: 0.8332 - val_loss: 0.6600 - learning_rate: 1.0000e-05
# Epoch 16/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 384ms/step - accuracy: 0.5275 - loss: 1.3414 - val_accuracy: 0.8597 - val_loss: 0.5556 - learning_rate: 1.0000e-05
# Epoch 17/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 82s 383ms/step - accuracy: 0.5562 - loss: 1.2901 - val_accuracy: 0.8716 - val_loss: 0.4884 - learning_rate: 1.0000e-05
# Epoch 18/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 386ms/step - accuracy: 0.5644 - loss: 1.2482 - val_accuracy: 0.8962 - val_loss: 0.4319 - learning_rate: 1.0000e-05
# Epoch 19/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 387ms/step - accuracy: 0.5844 - loss: 1.2151 - val_accuracy: 0.9056 - val_loss: 0.3605 - learning_rate: 1.0000e-05
# Epoch 20/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 385ms/step - accuracy: 0.6042 - loss: 1.1490 - val_accuracy: 0.9188 - val_loss: 0.3036 - learning_rate: 1.0000e-05
# Epoch 21/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 388ms/step - accuracy: 0.6188 - loss: 1.1121 - val_accuracy: 0.9270 - val_loss: 0.2768 - learning_rate: 1.0000e-05
# Epoch 22/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 384ms/step - accuracy: 0.6114 - loss: 1.1041 - val_accuracy: 0.9383 - val_loss: 0.2356 - learning_rate: 1.0000e-05
# Epoch 23/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 385ms/step - accuracy: 0.6384 - loss: 1.0734 - val_accuracy: 0.9446 - val_loss: 0.1986 - learning_rate: 1.0000e-05
# Epoch 24/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 385ms/step - accuracy: 0.6440 - loss: 1.0409 - val_accuracy: 0.9497 - val_loss: 0.1742 - learning_rate: 1.0000e-05
# Epoch 25/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 388ms/step - accuracy: 0.6501 - loss: 1.0363 - val_accuracy: 0.9572 - val_loss: 0.1462 - learning_rate: 1.0000e-05
# Epoch 26/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 390ms/step - accuracy: 0.6528 - loss: 1.0087 - val_accuracy: 0.9597 - val_loss: 0.1360 - learning_rate: 1.0000e-05
# Epoch 27/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 388ms/step - accuracy: 0.6598 - loss: 1.0087 - val_accuracy: 0.9717 - val_loss: 0.1204 - learning_rate: 1.0000e-05
# Epoch 28/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 380ms/step - accuracy: 0.6547 - loss: 0.9984 - val_accuracy: 0.9679 - val_loss: 0.1156 - learning_rate: 1.0000e-05
# Epoch 29/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 380ms/step - accuracy: 0.6666 - loss: 0.9734 - val_accuracy: 0.9711 - val_loss: 0.1060 - learning_rate: 1.0000e-05
# Epoch 30/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 388ms/step - accuracy: 0.7001 - loss: 0.8892 - val_accuracy: 0.9729 - val_loss: 0.1006 - learning_rate: 1.0000e-05
# Epoch 31/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 386ms/step - accuracy: 0.6703 - loss: 0.9590 - val_accuracy: 0.9761 - val_loss: 0.0914 - learning_rate: 1.0000e-05
# Epoch 32/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 383ms/step - accuracy: 0.6774 - loss: 0.9272 - val_accuracy: 0.9780 - val_loss: 0.0872 - learning_rate: 1.0000e-05
# Epoch 33/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 387ms/step - accuracy: 0.6676 - loss: 0.9546 - val_accuracy: 0.9786 - val_loss: 0.0808 - learning_rate: 1.0000e-05
# Epoch 34/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 387ms/step - accuracy: 0.6997 - loss: 0.8595 - val_accuracy: 0.9811 - val_loss: 0.0755 - learning_rate: 1.0000e-05
# Epoch 35/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 391ms/step - accuracy: 0.6682 - loss: 0.9651 - val_accuracy: 0.9817 - val_loss: 0.0710 - learning_rate: 1.0000e-05
# Epoch 36/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 380ms/step - accuracy: 0.6887 - loss: 0.8893 - val_accuracy: 0.9817 - val_loss: 0.0712 - learning_rate: 1.0000e-05
# Epoch 37/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.6962 - loss: 0.8768 - val_accuracy: 0.9805 - val_loss: 0.0649 - learning_rate: 1.0000e-05
# Epoch 38/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.7046 - loss: 0.8636 - val_accuracy: 0.9817 - val_loss: 0.0615 - learning_rate: 1.0000e-05
# Epoch 39/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 384ms/step - accuracy: 0.7041 - loss: 0.8643 - val_accuracy: 0.9824 - val_loss: 0.0608 - learning_rate: 1.0000e-05
# Epoch 40/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 382ms/step - accuracy: 0.7084 - loss: 0.8387 - val_accuracy: 0.9817 - val_loss: 0.0564 - learning_rate: 1.0000e-05
# Epoch 41/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 383ms/step - accuracy: 0.7075 - loss: 0.8319 - val_accuracy: 0.9862 - val_loss: 0.0538 - learning_rate: 1.0000e-05
# Epoch 42/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 381ms/step - accuracy: 0.7065 - loss: 0.8536 - val_accuracy: 0.9868 - val_loss: 0.0502 - learning_rate: 1.0000e-05
# Epoch 43/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 400ms/step - accuracy: 0.7067 - loss: 0.8641 - val_accuracy: 0.9874 - val_loss: 0.0523 - learning_rate: 1.0000e-05
# Epoch 44/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 47s 383ms/step - accuracy: 0.7123 - loss: 0.8412 - val_accuracy: 0.9868 - val_loss: 0.0504 - learning_rate: 1.0000e-05
# Epoch 45/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 384ms/step - accuracy: 0.7273 - loss: 0.7815 - val_accuracy: 0.9868 - val_loss: 0.0503 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve, auc, accuracy_score

# Recheck Data Generators
test_generator = test_datagen.flow_from_directory(
    '/kaggle/input/saadnewdataset/dataset',  # Make sure this directory is correct
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # Ensure no shuffling for consistency in predictions
)

# 1. Evaluate model on the test set
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy from evaluate: {test_acc * 100:.2f}%')


# Evaluate the model on test set
predictions = model.predict(test_generator)
y_true = test_generator.classes
y_pred = np.argmax(predictions, axis=1)

# Calculate accuracy score
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot confusion matrix using Seaborn
plt.figure(figsize=(15, 15))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# Classification report
print("Classification Report:")
print(classification_report(y_true, y_pred))

# Calculate overall ROC AUC score
roc_auc = roc_auc_score(tf.keras.utils.to_categorical(y_true), predictions, average='macro')
print("Overall ROC AUC Score:", roc_auc)

# Plot ROC curve
fpr, tpr, _ = roc_curve(tf.keras.utils.to_categorical(y_true).ravel(), predictions.ravel())
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.5f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve EfficientNet')
plt.legend(loc="lower right")
plt.show()

# Plot loss and accuracy per epoch
plt.figure(figsize=(12, 6))

# Plot training loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Found 5314 images belonging to 10 classes.
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 11s 64ms/step - accuracy: 0.9864 - loss: 0.0565
# W0000 00:00:1720293200.380206     179 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Test accuracy from evaluate: 98.46%
#   5/167 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step
# W0000 00:00:1720293213.331714     179 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step
# W0000 00:00:1720293224.465247     180 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Accuracy: 0.9845690628528415
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       526
#            1       0.98      0.99      0.98       534
#            2       0.99      0.98      0.99       533
#            3       0.98      0.97      0.97       531
#            4       1.00      0.99      1.00       532
#            5       0.98      0.98      0.98       532
#            6       0.98      0.97      0.98       532
#            7       0.99      1.00      0.99       533
#            8       0.98      0.99      0.99       531
#            9       0.99      0.98      0.98       530
#
#     accuracy                           0.98      5314
#    macro avg       0.98      0.98      0.98      5314
# weighted avg       0.98      0.98      0.98      5314
#
# Overall ROC AUC Score: 0.9996632001191745
