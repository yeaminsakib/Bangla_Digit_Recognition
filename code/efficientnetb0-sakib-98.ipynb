# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import seaborn as sns
import os
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D
from keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve, auc
# Out:
# 2024-07-06 17:22:10.319769: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-06 17:22:10.319867: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-06 17:22:10.429566: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# # Google colab connection
# from google.colab import drive
# drive.mount('/content/drive')
# !unzip "/content/dataset.zip"

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the directory paths
data_dir = '/kaggle/input/saadnewdataset/dataset'
img_size = (224, 224)
batch_size = 32

# Create ImageDataGenerator instances for train, validation, and test sets with augmentation for training set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=60,
    width_shift_range=0.5,
    height_shift_range=0.5,
    shear_range=0.5,
    zoom_range=0.5,
    horizontal_flip=True,
    validation_split=0.3  # Increase validation split to 30%
)

validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=True
)
# Out:
# Found 3725 images belonging to 10 classes.
# Found 1589 images belonging to 10 classes.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.regularizers import l2

# Load the ResNet50 model pre-trained on ImageNet
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add custom layers on top of the base model
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(64, activation='relu')(x)  # Reduce the number of units
x = Dropout(0.5)(x)  # Increase dropout
predictions = Dense(10, activation='softmax')(x)  # Assuming you have 10 classes

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Make all layers trainable for fine-tuning
for layer in base_model.layers:
    layer.trainable = True

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Define callbacks
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, min_lr=1e-7)

# Train the model
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=[checkpoint, early_stopping, reduce_lr]
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720286647.174429     177 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1720286647.274603     177 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  27/117 ━━━━━━━━━━━━━━━━━━━━ 4:05 3s/step - accuracy: 0.0790 - loss: 2.3968
# W0000 00:00:1720286718.189320     177 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 963ms/step - accuracy: 0.0909 - loss: 2.3831
# W0000 00:00:1720286765.463491     179 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1720286780.906281     180 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - accuracy: 0.0909 - loss: 2.3831 - val_accuracy: 0.1007 - val_loss: 2.3258 - learning_rate: 1.0000e-05
# Epoch 2/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 389ms/step - accuracy: 0.1083 - loss: 2.3514 - val_accuracy: 0.0906 - val_loss: 2.3126 - learning_rate: 1.0000e-05
# Epoch 3/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 394ms/step - accuracy: 0.1239 - loss: 2.3303 - val_accuracy: 0.0868 - val_loss: 2.2997 - learning_rate: 1.0000e-05
# Epoch 4/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 395ms/step - accuracy: 0.1250 - loss: 2.3277 - val_accuracy: 0.1668 - val_loss: 2.2797 - learning_rate: 1.0000e-05
# Epoch 5/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 385ms/step - accuracy: 0.1292 - loss: 2.2964 - val_accuracy: 0.1296 - val_loss: 2.2512 - learning_rate: 1.0000e-05
# Epoch 6/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 389ms/step - accuracy: 0.1581 - loss: 2.2559 - val_accuracy: 0.1712 - val_loss: 2.2195 - learning_rate: 1.0000e-05
# Epoch 7/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 396ms/step - accuracy: 0.1741 - loss: 2.2372 - val_accuracy: 0.2649 - val_loss: 2.1403 - learning_rate: 1.0000e-05
# Epoch 8/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 392ms/step - accuracy: 0.1732 - loss: 2.2150 - val_accuracy: 0.4160 - val_loss: 1.9842 - learning_rate: 1.0000e-05
# Epoch 9/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 391ms/step - accuracy: 0.2197 - loss: 2.1652 - val_accuracy: 0.4902 - val_loss: 1.8317 - learning_rate: 1.0000e-05
# Epoch 10/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 397ms/step - accuracy: 0.2518 - loss: 2.1161 - val_accuracy: 0.5563 - val_loss: 1.6863 - learning_rate: 1.0000e-05
# Epoch 11/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 388ms/step - accuracy: 0.2818 - loss: 2.0437 - val_accuracy: 0.6375 - val_loss: 1.5172 - learning_rate: 1.0000e-05
# Epoch 12/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 398ms/step - accuracy: 0.2967 - loss: 1.9909 - val_accuracy: 0.7067 - val_loss: 1.3353 - learning_rate: 1.0000e-05
# Epoch 13/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 396ms/step - accuracy: 0.3289 - loss: 1.9068 - val_accuracy: 0.7590 - val_loss: 1.1770 - learning_rate: 1.0000e-05
# Epoch 14/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 389ms/step - accuracy: 0.3803 - loss: 1.7953 - val_accuracy: 0.7873 - val_loss: 1.0243 - learning_rate: 1.0000e-05
# Epoch 15/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 390ms/step - accuracy: 0.4108 - loss: 1.7253 - val_accuracy: 0.8137 - val_loss: 0.8858 - learning_rate: 1.0000e-05
# Epoch 16/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 393ms/step - accuracy: 0.4241 - loss: 1.6604 - val_accuracy: 0.8383 - val_loss: 0.7501 - learning_rate: 1.0000e-05
# Epoch 17/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - accuracy: 0.4677 - loss: 1.5751 - val_accuracy: 0.8540 - val_loss: 0.6456 - learning_rate: 1.0000e-05
# Epoch 18/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 391ms/step - accuracy: 0.4890 - loss: 1.5132 - val_accuracy: 0.8584 - val_loss: 0.5585 - learning_rate: 1.0000e-05
# Epoch 19/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 394ms/step - accuracy: 0.4977 - loss: 1.4771 - val_accuracy: 0.8811 - val_loss: 0.4858 - learning_rate: 1.0000e-05
# Epoch 20/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 394ms/step - accuracy: 0.5188 - loss: 1.4056 - val_accuracy: 0.8811 - val_loss: 0.4383 - learning_rate: 1.0000e-05
# Epoch 21/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 397ms/step - accuracy: 0.5301 - loss: 1.3505 - val_accuracy: 0.8905 - val_loss: 0.3914 - learning_rate: 1.0000e-05
# Epoch 22/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 393ms/step - accuracy: 0.5595 - loss: 1.3057 - val_accuracy: 0.8980 - val_loss: 0.3552 - learning_rate: 1.0000e-05
# Epoch 23/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 395ms/step - accuracy: 0.5744 - loss: 1.2550 - val_accuracy: 0.9056 - val_loss: 0.3253 - learning_rate: 1.0000e-05
# Epoch 24/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 64s 520ms/step - accuracy: 0.5775 - loss: 1.2437 - val_accuracy: 0.9245 - val_loss: 0.2881 - learning_rate: 1.0000e-05
# Epoch 25/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 54s 426ms/step - accuracy: 0.5946 - loss: 1.1802 - val_accuracy: 0.9352 - val_loss: 0.2603 - learning_rate: 1.0000e-05
# Epoch 26/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 392ms/step - accuracy: 0.5888 - loss: 1.1772 - val_accuracy: 0.9402 - val_loss: 0.2366 - learning_rate: 1.0000e-05
# Epoch 27/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 397ms/step - accuracy: 0.6363 - loss: 1.0860 - val_accuracy: 0.9490 - val_loss: 0.2178 - learning_rate: 1.0000e-05
# Epoch 28/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 393ms/step - accuracy: 0.6105 - loss: 1.1267 - val_accuracy: 0.9503 - val_loss: 0.2061 - learning_rate: 1.0000e-05
# Epoch 29/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 58s 470ms/step - accuracy: 0.5988 - loss: 1.1422 - val_accuracy: 0.9585 - val_loss: 0.1871 - learning_rate: 1.0000e-05
# Epoch 30/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 53s 426ms/step - accuracy: 0.6290 - loss: 1.0609 - val_accuracy: 0.9559 - val_loss: 0.1785 - learning_rate: 1.0000e-05
# Epoch 31/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 63s 509ms/step - accuracy: 0.6392 - loss: 1.0599 - val_accuracy: 0.9572 - val_loss: 0.1717 - learning_rate: 1.0000e-05
# Epoch 32/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 68s 554ms/step - accuracy: 0.6373 - loss: 1.0513 - val_accuracy: 0.9622 - val_loss: 0.1574 - learning_rate: 1.0000e-05
# Epoch 33/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 66s 538ms/step - accuracy: 0.6561 - loss: 1.0132 - val_accuracy: 0.9629 - val_loss: 0.1439 - learning_rate: 1.0000e-05
# Epoch 34/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 50s 397ms/step - accuracy: 0.6675 - loss: 0.9812 - val_accuracy: 0.9685 - val_loss: 0.1370 - learning_rate: 1.0000e-05
# Epoch 35/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - accuracy: 0.6300 - loss: 1.0570 - val_accuracy: 0.9692 - val_loss: 0.1296 - learning_rate: 1.0000e-05
# Epoch 36/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 395ms/step - accuracy: 0.6601 - loss: 0.9886 - val_accuracy: 0.9698 - val_loss: 0.1214 - learning_rate: 1.0000e-05
# Epoch 37/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - accuracy: 0.6623 - loss: 0.9895 - val_accuracy: 0.9717 - val_loss: 0.1142 - learning_rate: 1.0000e-05
# Epoch 38/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 398ms/step - accuracy: 0.6785 - loss: 0.9490 - val_accuracy: 0.9723 - val_loss: 0.1088 - learning_rate: 1.0000e-05
# Epoch 39/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 394ms/step - accuracy: 0.6842 - loss: 0.9283 - val_accuracy: 0.9742 - val_loss: 0.1027 - learning_rate: 1.0000e-05
# Epoch 40/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - accuracy: 0.6724 - loss: 0.9432 - val_accuracy: 0.9755 - val_loss: 0.0986 - learning_rate: 1.0000e-05
# Epoch 41/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 50s 407ms/step - accuracy: 0.6790 - loss: 0.9161 - val_accuracy: 0.9755 - val_loss: 0.0923 - learning_rate: 1.0000e-05
# Epoch 42/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 398ms/step - accuracy: 0.6941 - loss: 0.9077 - val_accuracy: 0.9767 - val_loss: 0.0914 - learning_rate: 1.0000e-05
# Epoch 43/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 397ms/step - accuracy: 0.7082 - loss: 0.8674 - val_accuracy: 0.9780 - val_loss: 0.0839 - learning_rate: 1.0000e-05
# Epoch 44/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 394ms/step - accuracy: 0.6712 - loss: 0.9640 - val_accuracy: 0.9761 - val_loss: 0.0806 - learning_rate: 1.0000e-05
# Epoch 45/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 393ms/step - accuracy: 0.6886 - loss: 0.9051 - val_accuracy: 0.9780 - val_loss: 0.0770 - learning_rate: 1.0000e-05
# Epoch 46/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 390ms/step - accuracy: 0.6834 - loss: 0.9297 - val_accuracy: 0.9792 - val_loss: 0.0739 - learning_rate: 1.0000e-05
# Epoch 47/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 389ms/step - accuracy: 0.6962 - loss: 0.8828 - val_accuracy: 0.9792 - val_loss: 0.0710 - learning_rate: 1.0000e-05
# Epoch 48/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 49s 399ms/step - accuracy: 0.6848 - loss: 0.9150 - val_accuracy: 0.9817 - val_loss: 0.0665 - learning_rate: 1.0000e-05
# Epoch 49/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 48s 388ms/step - accuracy: 0.7014 - loss: 0.8636 - val_accuracy: 0.9811 - val_loss: 0.0685 - learning_rate: 1.0000e-05
# Epoch 50/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 61s 495ms/step - accuracy: 0.7048 - loss: 0.8611 - val_accuracy: 0.9817 - val_loss: 0.0637 - learning_rate: 1.0000e-05

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve, auc, accuracy_score

# Recheck Data Generators
test_generator = test_datagen.flow_from_directory(
    '/kaggle/input/saadnewdataset/dataset',  # Make sure this directory is correct
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # Ensure no shuffling for consistency in predictions
)

# 1. Evaluate model on the test set
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy from evaluate: {test_acc * 100:.2f}%')


# Evaluate the model on test set
predictions = model.predict(test_generator)
y_true = test_generator.classes
y_pred = np.argmax(predictions, axis=1)

# Calculate accuracy score
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot confusion matrix using Seaborn
plt.figure(figsize=(15, 15))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# Classification report
print("Classification Report:")
print(classification_report(y_true, y_pred))

# Calculate overall ROC AUC score
roc_auc = roc_auc_score(tf.keras.utils.to_categorical(y_true), predictions, average='macro')
print("Overall ROC AUC Score:", roc_auc)

# Plot ROC curve
fpr, tpr, _ = roc_curve(tf.keras.utils.to_categorical(y_true).ravel(), predictions.ravel())
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.5f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve EfficientNet')
plt.legend(loc="lower right")
plt.show()

# Plot loss and accuracy per epoch
plt.figure(figsize=(12, 6))

# Plot training loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Found 5314 images belonging to 10 classes.
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.9796 - loss: 0.0741
# Test accuracy from evaluate: 98.02%
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step
# Accuracy: 0.9802408731652239
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       526
#            1       0.97      0.99      0.98       534
#            2       0.99      0.99      0.99       533
#            3       0.96      0.97      0.97       531
#            4       0.99      1.00      0.99       532
#            5       0.97      0.97      0.97       532
#            6       0.98      0.96      0.97       532
#            7       0.99      0.99      0.99       533
#            8       0.99      0.98      0.99       531
#            9       0.98      0.97      0.98       530
#
#     accuracy                           0.98      5314
#    macro avg       0.98      0.98      0.98      5314
# weighted avg       0.98      0.98      0.98      5314
#
# Overall ROC AUC Score: 0.9995215893789515
